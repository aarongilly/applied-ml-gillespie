# %% [markdown]
# # Lab 2 - Exploring and manipulating data.
# Here is what we we do:
# 1. Read in the data from a CSV file and do simple visualizations
# 2. Look for patterns in the data
# 3. Deal with missing values
# 4. Add in new features
# 5. Split and graph

# %% [markdown]
# ### Read the CSV file:
# We will use info() on the data frame to get a first look.  This is mostly a quick sanity check

# %%
# third cell -
import pandas as pd
howell_full = pd.read_csv("Howell.csv", sep=";")

# %% [markdown]
# ### Quick look at distributions:

# %%
print(howell_full.head(n=10))
# Out:
#     height     weight   age  male
# 0  151.765  47.825606  63.0     1
# 1  139.700  36.485807  63.0     0
# 2  136.525  31.864838  65.0     0
# 3  156.845  53.041914  41.0     1
# 4  145.415  41.276872  51.0     0
# 5  163.830  62.992589  35.0     1
# 6  149.225  38.243476  32.0     0
# 7  168.910  55.479971  27.0     1
# 8  147.955  34.869885  19.0     0
# 9  165.100  54.487739  54.0     1

# %%
print(howell_full.describe())
# Out:
#            height      weight         age        male
# count  544.000000  544.000000  544.000000  544.000000
# mean   138.263596   35.610618   29.344393    0.472426
# std     27.602448   14.719178   20.746888    0.499699
# min     53.975000    4.252425    0.000000    0.000000
# 25%    125.095000   22.007717   12.000000    0.000000
# 50%    148.590000   40.057844   27.000000    0.000000
# 75%    157.480000   47.209005   43.000000    1.000000
# max    179.070000   62.992589   88.000000    1.000000

# %%
howell_full.corr()
# Out:
#           height    weight       age      male
# height  1.000000  0.940822  0.683689  0.139229
# weight  0.940822  1.000000  0.678335  0.155443
# age     0.683689  0.678335  1.000000  0.005887
# male    0.139229  0.155443  0.005887  1.000000

# %% [markdown]
# ### Quick Visualization

# %%
from pandas.plotting import scatter_matrix

attributes = ['height', 'weight', 'age']
scatter_matrix(howell_full[attributes])
# Out:
# array([[<Axes: xlabel='height', ylabel='height'>,
#         <Axes: xlabel='weight', ylabel='height'>,
#         <Axes: xlabel='age', ylabel='height'>],
#        [<Axes: xlabel='height', ylabel='weight'>,
#         <Axes: xlabel='weight', ylabel='weight'>,
#         <Axes: xlabel='age', ylabel='weight'>],
#        [<Axes: xlabel='height', ylabel='age'>,
#         <Axes: xlabel='weight', ylabel='age'>,
#         <Axes: xlabel='age', ylabel='age'>]], dtype=object)

# %%
import matplotlib.pyplot as plt
height = howell_full['height']
weight = howell_full['weight']
plt.scatter(height, weight)
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.show()

# %% [markdown]
# ### A Better Plot

# %%
gender = howell_full['male']
plt.scatter(height, weight, c=gender)
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.show()

# %% [markdown]
# ### Handling Missing Data
# In our case we have no missing data, so the code here is just for reference.

# %%
# create a new feature with the name new
howell_full['new'] = howell_full['male'] + howell_full['age']
howell_full.info()

# get rid of the new feature
howell_full.drop(axis='columns', labels='new', inplace=True)
howell_full.info()

# remove rows that are missing values
howell_full.dropna(axis='index', how="any", inplace=True)

height_median = howell_full['height'].median()
weight_average = howell_full['weight'].mean()

# replace missing values by median or average (or any arbitrary value)
howell_full['height'].fillna(height_median, inplace=True)
howell_full['weight'].fillna(weight_average, inplace=True)
howell_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 544 entries, 0 to 543
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   height  544 non-null    float64
#  1   weight  544 non-null    float64
#  2   age     544 non-null    float64
#  3   male    544 non-null    int64
#  4   new     544 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 21.4 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 544 entries, 0 to 543
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   height  544 non-null    float64
#  1   weight  544 non-null    float64
#  2   age     544 non-null    float64
#  3   male    544 non-null    int64
# dtypes: float64(3), int64(1)
# memory usage: 17.1 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 544 entries, 0 to 543
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   height  544 non-null    float64
#  1   weight  544 non-null    float64
#  2   age     544 non-null    float64
#  3   male    544 non-null    int64
# dtypes: float64(3), int64(1)
# memory usage: 17.1 KB
# /var/folders/hk/h6rz0nm939n_y0ssynfrg63r0000gn/T/ipykernel_10491/2979336195.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   howell_full['height'].fillna(height_median, inplace=True)
# /var/folders/hk/h6rz0nm939n_y0ssynfrg63r0000gn/T/ipykernel_10491/2979336195.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   howell_full['weight'].fillna(weight_average, inplace=True)

# %% [markdown]
# ### Adding a New Feature

# %%
# Compute bmi based on height and weight metric units
def bmi(height, weight):
 return 10000*weight/(height**2)
print(bmi(150, 40))
new_feature = bmi(howell_full['height'], howell_full['weight'])
print(new_feature)
howell_full['bmi'] = new_feature
howell_full.head(n=10)
# Out:
# 17.77777777777778
# 0      20.764297
# 1      18.695244
# 2      17.095718
# 3      21.561444
# 4      19.520384
#          ...
# 539    14.720729
# 540    19.739486
# 541    22.155341
# 542    15.917698
# 543    20.844590
# Length: 544, dtype: float64
#     height     weight   age  male        bmi
# 0  151.765  47.825606  63.0     1  20.764297
# 1  139.700  36.485807  63.0     0  18.695244
# 2  136.525  31.864838  65.0     0  17.095718
# 3  156.845  53.041914  41.0     1  21.561444
# 4  145.415  41.276872  51.0     0  19.520384
# 5  163.830  62.992589  35.0     1  23.469433
# 6  149.225  38.243476  32.0     0  17.174108
# 7  168.910  55.479971  27.0     1  19.445786
# 8  147.955  34.869885  19.0     0  15.929099
# 9  165.100  54.487739  54.0     1  19.989625

# %% [markdown]
# ### Creating a categorical feature
# When doing a stratefied sampling, we need a feature that is categorical.  In other words, a feature that has a limited number of values. BMI is continuous.  We probably do not have very many instances that share the same BMI.  BMI already has some arbitraily determined categories:
#     - Underweight less than 18.5
#     - Normal range of 18.5 to 25.0
#     - Overwieght range of 25.0 to 30.0
#     - Obese greater than 30
#
# Unlike the BMI function, IF does not get applied across an array, so we need to create a version of the function that will.

# %%
import numpy as np

def bmi_category(bmi):
 # bmi can only be a single value
 if bmi < 18.5: return 'Underweight'
 if bmi < 25.0: return 'Normal'
 if bmi < 30.0: return 'Overweight'
 return 'Obese'

vector_bmi_category = np.vectorize(bmi_category)
howell_full['bmi class'] = vector_bmi_category(howell_full['bmi'])
print(howell_full.head(n=10))
howell_full['bmi class'].value_counts()
# Out:
#     height     weight   age  male        bmi    bmi class
# 0  151.765  47.825606  63.0     1  20.764297       Normal
# 1  139.700  36.485807  63.0     0  18.695244       Normal
# 2  136.525  31.864838  65.0     0  17.095718  Underweight
# 3  156.845  53.041914  41.0     1  21.561444       Normal
# 4  145.415  41.276872  51.0     0  19.520384       Normal
# 5  163.830  62.992589  35.0     1  23.469433       Normal
# 6  149.225  38.243476  32.0     0  17.174108  Underweight
# 7  168.910  55.479971  27.0     1  19.445786       Normal
# 8  147.955  34.869885  19.0     0  15.929099  Underweight
# 9  165.100  54.487739  54.0     1  19.989625       Normal
# bmi class
# Underweight    341
# Normal         202
# Overweight       1
# Name: count, dtype: int64

# %% [markdown]
# ### Splitting the Data by Age

# %%
over18 = howell_full["age"] > 18
print(over18)

# Only keep the true instances
howell_adults = howell_full[over18]
howell_children = howell_full[~over18] # ~ is not in numpy
print("There are ", len(howell_adults), " adult instances")
print(howell_adults)
print("There are ", len(howell_children), " child instances")
print(howell_children)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 539    False
# 540     True
# 541     True
# 542    False
# 543     True
# Name: age, Length: 544, dtype: bool
# There are  346  adult instances
#       height     weight   age  male        bmi    bmi class
# 0    151.765  47.825606  63.0     1  20.764297       Normal
# 1    139.700  36.485807  63.0     0  18.695244       Normal
# 2    136.525  31.864838  65.0     0  17.095718  Underweight
# 3    156.845  53.041914  41.0     1  21.561444       Normal
# 4    145.415  41.276872  51.0     0  19.520384       Normal
# ..       ...        ...   ...   ...        ...          ...
# 534  162.560  47.031821  27.0     0  17.797722  Underweight
# 537  142.875  34.246196  31.0     0  16.776442  Underweight
# 540  162.560  52.163080  31.0     1  19.739486       Normal
# 541  156.210  54.062497  21.0     0  22.155341       Normal
# 543  158.750  52.531624  68.0     1  20.844590       Normal
#
# [346 rows x 6 columns]
# There are  198  child instances
#       height     weight   age  male        bmi    bmi class
# 18   121.920  19.617854  12.0     1  13.197801  Underweight
# 19   105.410  13.947954   8.0     0  12.552981  Underweight
# 20    86.360  10.489315   6.5     0  14.064421  Underweight
# 23   129.540  23.586784  13.0     1  14.055974  Underweight
# 24   109.220  15.989118   7.0     0  13.403560  Underweight
# ..       ...        ...   ...   ...        ...          ...
# 535  114.935  17.519991   7.0     1  13.262619  Underweight
# 536   67.945   7.229122   1.0     0  15.659236  Underweight
# 538   76.835   8.022908   1.0     1  13.589818  Underweight
# 539  145.415  31.127751  17.0     1  14.720729  Underweight
# 542   71.120   8.051258   0.0     1  15.917698  Underweight
#
# [198 rows x 6 columns]

# %% [markdown]
# ### Plot with Masking
# Another way to restrict the instances you use is to apply masking to a numpy array. We replace certain values in the array with a mask. (This is not a NaN... the value is still there, it just won't be used.)
#
# In this plot we are only using the adult instances (howell_adult) and we are going to create masks for male and female  (male is 1 or 0)

# %%
import matplotlib.pyplot as plt

male_height = np.ma.masked_where(howell_adults['male']==0, howell_adults['height'])
female_height = np.ma.masked_where(howell_adults['male']==1, howell_adults['height'])
weight = howell_adults['weight']
plt.scatter(male_height, weight, c='red', marker='+')
plt.scatter(female_height, weight, c='blue', marker='^')
plt.xlabel('weight')
plt.ylabel('height')
plt.legend(['Male', 'Female'])
plt.show()

# %% [markdown]
# ### Train/Test Data Split

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(howell_adults,test_size=0.2, random_state=123)

print('Train size: ', len(train_set), 'Test size: ', len(test_set))
print('Adult counts', howell_adults['male'].value_counts())
print('Train counts', train_set['male'].value_counts())
print('Test counts', test_set['male'].value_counts())
# Out:
# Train size:  276 Test size:  70
# Adult counts male
# 0    182
# 1    164
# Name: count, dtype: int64
# Train counts male
# 0    141
# 1    135
# Name: count, dtype: int64
# Test counts male
# 0    41
# 1    29
# Name: count, dtype: int64

# %% [markdown]
# ### Stratified Test/Train Data Split

# %%
from sklearn.model_selection import StratifiedShuffleSplit

splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2,random_state=123)

for train_indices, test_indices in splitter.split(howell_adults,howell_adults['male']):
 train_set = howell_adults.iloc[train_indices]
 test_set = howell_adults.iloc[test_indices]

print('Train size: ', len(train_set), 'Test size: ', len(test_set))
print('Adult counts', howell_adults['male'].value_counts())
print('Train counts', train_set['male'].value_counts())
print('Test counts', test_set['male'].value_counts())
# Out:
# Train size:  276 Test size:  70
# Adult counts male
# 0    182
# 1    164
# Name: count, dtype: int64
# Train counts male
# 0    145
# 1    131
# Name: count, dtype: int64
# Test counts male
# 0    37
# 1    33
# Name: count, dtype: int64

# %% [markdown]
# # Lab 3 Stuff - in theory I added a gitignore for this stuff

# %%
# Define the input features before splitting
# Case 1: Height only
X = howell_adults[['height']]
y = howell_adults['male']

# Case 2: Weight only
# X = howell_adults[['weight']]
# y = howell_adults['male']

# Case 3: Height + Weight
# X = howell_adults[['height', 'weight']]
# y = howell_adults['male']

# %%
from sklearn.model_selection import StratifiedShuffleSplit

splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=123)

for train_indices, test_indices in splitter.split(X, y):
    X_train = X.iloc[train_indices]
    X_test = X.iloc[test_indices]
    y_train = y.iloc[train_indices]
    y_test = y.iloc[test_indices]

print('Train size: ', len(X_train), 'Test size: ', len(X_test))
# Out:
# Train size:  276 Test size:  70

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix

tree_model = DecisionTreeClassifier()
tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Predict and evaluate training data (X train)
y_pred = tree_model.predict(X_train)  
print("Results for Decision Tree on training data:")  
print(classification_report(y_train, y_pred))
# Out:
# Results for Decision Tree on training data:
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91       145
#            1       0.95      0.83      0.89       131
#
#     accuracy                           0.90       276
#    macro avg       0.91      0.90      0.90       276
# weighted avg       0.90      0.90      0.90       276

# %%
# Predict and evaluate test data
y_test_pred = tree_model.predict(X_test)
print("Results for Decision Tree on test data:")
print(classification_report(y_test, y_test_pred))
# Out:
# Results for Decision Tree on test data:
#               precision    recall  f1-score   support
#
#            0       0.79      0.89      0.84        37
#            1       0.86      0.73      0.79        33
#
#     accuracy                           0.81        70
#    macro avg       0.82      0.81      0.81        70
# weighted avg       0.82      0.81      0.81        70

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_test, y_test_pred)
sns.heatmap(cm, annot=True, cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(25,20))
plot_tree(tree_model,feature_names=['height', 'weight'],class_names=['female', 'male'],filled=True)
# Out:
# [Text(0.5776515151515151, 0.95, 'height <= 156.528\ngini = 0.499\nsamples = 276\nvalue = [145, 131]\nclass = female'),
#  Text(0.3068181818181818, 0.85, 'height <= 150.812\ngini = 0.26\nsamples = 163\nvalue = [138, 25]\nclass = female'),
#  Text(0.4422348484848485, 0.8999999999999999, 'True  '),
#  Text(0.13636363636363635, 0.75, 'height <= 142.24\ngini = 0.133\nsamples = 98\nvalue = [91, 7]\nclass = female'),
#  Text(0.06060606060606061, 0.65, 'height <= 139.382\ngini = 0.278\nsamples = 12\nvalue = [10, 2]\nclass = female'),
#  Text(0.030303030303030304, 0.55, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = female'),
#  Text(0.09090909090909091, 0.55, 'height <= 140.018\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = female'),
#  Text(0.06060606060606061, 0.45, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = female'),
#  Text(0.12121212121212122, 0.45, 'height <= 141.287\ngini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = female'),
#  Text(0.09090909090909091, 0.35, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = female'),
#  Text(0.15151515151515152, 0.35, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = female'),
#  Text(0.21212121212121213, 0.65, 'height <= 146.225\ngini = 0.11\nsamples = 86\nvalue = [81, 5]\nclass = female'),
#  Text(0.18181818181818182, 0.55, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]\nclass = female'),
#  Text(0.24242424242424243, 0.55, 'height <= 146.542\ngini = 0.165\nsamples = 55\nvalue = [50, 5]\nclass = female'),
#  Text(0.21212121212121213, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = male'),
#  Text(0.2727272727272727, 0.45, 'height <= 147.01\ngini = 0.137\nsamples = 54\nvalue = [50, 4]\nclass = female'),
#  Text(0.21212121212121213, 0.35, 'height <= 146.692\ngini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = female'),
#  Text(0.18181818181818182, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = female'),
#  Text(0.24242424242424243, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]\nclass = female'),
#  Text(0.3333333333333333, 0.35, 'height <= 148.438\ngini = 0.113\nsamples = 50\nvalue = [47, 3]\nclass = female'),
#  Text(0.30303030303030304, 0.25, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]\nclass = female'),
#  Text(0.36363636363636365, 0.25, 'height <= 149.543\ngini = 0.17\nsamples = 32\nvalue = [29, 3]\nclass = female'),
#  Text(0.3333333333333333, 0.15, 'height <= 148.908\ngini = 0.305\nsamples = 16\nvalue = [13, 3]\nclass = female'),
#  Text(0.30303030303030304, 0.05, 'gini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = female'),
#  Text(0.36363636363636365, 0.05, 'gini = 0.346\nsamples = 9\nvalue = [7, 2]\nclass = female'),
#  Text(0.3939393939393939, 0.15, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]\nclass = female'),
#  Text(0.4772727272727273, 0.75, 'height <= 151.968\ngini = 0.4\nsamples = 65\nvalue = [47, 18]\nclass = female'),
#  Text(0.3939393939393939, 0.65, 'height <= 151.854\ngini = 0.49\nsamples = 14\nvalue = [8, 6]\nclass = female'),
#  Text(0.36363636363636365, 0.55, 'height <= 151.448\ngini = 0.473\nsamples = 13\nvalue = [8, 5]\nclass = female'),
#  Text(0.3333333333333333, 0.45, 'gini = 0.408\nsamples = 7\nvalue = [5, 2]\nclass = female'),
#  Text(0.3939393939393939, 0.45, 'gini = 0.5\nsamples = 6\nvalue = [3, 3]\nclass = female'),
#  Text(0.42424242424242425, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = male'),
#  Text(0.5606060606060606, 0.65, 'height <= 154.602\ngini = 0.36\nsamples = 51\nvalue = [39, 12]\nclass = female'),
#  Text(0.48484848484848486, 0.55, 'height <= 152.197\ngini = 0.285\nsamples = 29\nvalue = [24, 5]\nclass = female'),
#  Text(0.45454545454545453, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = female'),
#  Text(0.5151515151515151, 0.45, 'height <= 152.87\ngini = 0.293\nsamples = 28\nvalue = [23, 5]\nclass = female'),
#  Text(0.45454545454545453, 0.35, 'height <= 152.552\ngini = 0.26\nsamples = 13\nvalue = [11, 2]\nclass = female'),
#  Text(0.42424242424242425, 0.25, 'gini = 0.278\nsamples = 12\nvalue = [10, 2]\nclass = female'),
#  Text(0.48484848484848486, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = female'),
#  Text(0.5757575757575758, 0.35, 'height <= 153.987\ngini = 0.32\nsamples = 15\nvalue = [12, 3]\nclass = female'),
#  Text(0.5454545454545454, 0.25, 'height <= 153.353\ngini = 0.375\nsamples = 8\nvalue = [6, 2]\nclass = female'),
#  Text(0.5151515151515151, 0.15, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = female'),
#  Text(0.5757575757575758, 0.15, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = female'),
#  Text(0.6060606060606061, 0.25, 'gini = 0.245\nsamples = 7\nvalue = [6, 1]\nclass = female'),
#  Text(0.6363636363636364, 0.55, 'height <= 154.92\ngini = 0.434\nsamples = 22\nvalue = [15.0, 7.0]\nclass = female'),
#  Text(0.6060606060606061, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = male'),
#  Text(0.6666666666666666, 0.45, 'height <= 155.257\ngini = 0.408\nsamples = 21\nvalue = [15, 6]\nclass = female'),
#  Text(0.6363636363636364, 0.35, 'gini = 0.463\nsamples = 11\nvalue = [7, 4]\nclass = female'),
#  Text(0.696969696969697, 0.35, 'height <= 155.893\ngini = 0.32\nsamples = 10\nvalue = [8, 2]\nclass = female'),
#  Text(0.6666666666666666, 0.25, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]\nclass = female'),
#  Text(0.7272727272727273, 0.25, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]\nclass = female'),
#  Text(0.8484848484848485, 0.85, 'height <= 157.734\ngini = 0.116\nsamples = 113\nvalue = [7, 106]\nclass = male'),
#  Text(0.7130681818181819, 0.8999999999999999, '  False'),
#  Text(0.7878787878787878, 0.75, 'height <= 157.162\ngini = 0.408\nsamples = 14\nvalue = [4, 10]\nclass = male'),
#  Text(0.7575757575757576, 0.65, 'gini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = male'),
#  Text(0.8181818181818182, 0.65, 'gini = 0.444\nsamples = 9\nvalue = [3, 6]\nclass = male'),
#  Text(0.9090909090909091, 0.75, 'height <= 162.712\ngini = 0.059\nsamples = 99\nvalue = [3, 96]\nclass = male'),
#  Text(0.8787878787878788, 0.65, 'height <= 161.607\ngini = 0.098\nsamples = 58\nvalue = [3, 55]\nclass = male'),
#  Text(0.8181818181818182, 0.55, 'height <= 159.092\ngini = 0.044\nsamples = 44\nvalue = [1, 43]\nclass = male'),
#  Text(0.7878787878787878, 0.45, 'height <= 158.775\ngini = 0.165\nsamples = 11\nvalue = [1, 10]\nclass = male'),
#  Text(0.7575757575757576, 0.35, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = male'),
#  Text(0.8181818181818182, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = female'),
#  Text(0.8484848484848485, 0.45, 'gini = 0.0\nsamples = 33\nvalue = [0, 33]\nclass = male'),
#  Text(0.9393939393939394, 0.55, 'height <= 162.243\ngini = 0.245\nsamples = 14\nvalue = [2, 12]\nclass = male'),
#  Text(0.9090909090909091, 0.45, 'gini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = male'),
#  Text(0.9696969696969697, 0.45, 'gini = 0.245\nsamples = 7\nvalue = [1, 6]\nclass = male'),
#  Text(0.9393939393939394, 0.65, 'gini = 0.0\nsamples = 41\nvalue = [0, 41]\nclass = male')]

# %% [markdown]
# # Vector Classifer

# %%
from sklearn.svm import SVC

svc_model = SVC()
svc_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred_svc = svc_model.predict(X_test)

print("Results for SVC on test data:")
print(classification_report(y_test, y_pred_svc))
# Out:
# Results for SVC on test data:
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80        37
#            1       0.78      0.76      0.77        33
#
#     accuracy                           0.79        70
#    macro avg       0.79      0.78      0.78        70
# weighted avg       0.79      0.79      0.79        70

# %%
# get the values for the support vectors (the special instances)
support_x = [x for (x,y) in svc_model.support_vectors_]
support_y = [y for (x,y) in svc_model.support_vectors_]
plt.scatter(male_height, weight, c='yellow', marker='s')
plt.scatter(female_height, weight, c='cyan', marker='^')
plt.scatter(support_x, support_y, c='black', marker='+')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[247], line 2
#       1 # get the values for the support vectors (the special instances)
# ----> 2 support_x = [x for (x,y) in svc_model.support_vectors_]
#       3 support_y = [y for (x,y) in svc_model.support_vectors_]
#       4 plt.scatter(male_height, weight, c='yellow', marker='s')
#
# ValueError: not enough values to unpack (expected 2, got 1)
